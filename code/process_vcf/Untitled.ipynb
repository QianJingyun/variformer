# %%
import pandas as pd

# %%
file_path = "/home/jqian54/sulab/enformer_fine_tuning/code/process_vcf/ref_fasta_mismatches.tsv"
df = pd.read_csv(file_path, sep = '\t')
# Out:
# /tmp/ipykernel_1272768/2907986114.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep = '\t')

# %%
df.head()
# Out:
#   CHROM    POS VCF_REF FASTA_SEQ
# 0     1  10623       C         t
# 1     1  15274       G         a
# 2     1  16298       T         C
# 3     1  19004       G         a
# 4     1  28563       G         A

# %%
chrom_counts = df['CHROM'].value_counts().sort_index()

print(chrom_counts)
